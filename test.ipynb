# %%
import duckdb

con = duckdb.connect("jaffle_shop.duckdb")

# %%
con.execute("select * from information_schema.tables").df()
# Out:
#    table_catalog table_schema       table_name  table_type  \
# 0            NaN         main     raw_payments  BASE TABLE
# 1            NaN         main       raw_orders  BASE TABLE
# 2            NaN         main    raw_customers  BASE TABLE
# 3            NaN         main  orders__dbt_tmp  BASE TABLE
# 4            NaN         main        customers  BASE TABLE
# 5            NaN         main     stg_payments        VIEW
# 6            NaN         main    stg_customers        VIEW
# 7            NaN         main       stg_orders        VIEW
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
# ...

# %%
con.close()
